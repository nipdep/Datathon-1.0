# %% [markdown]
# training dataset with goe spreading coffeient.

# %%
import numpy as np 
import pandas as pd 
import matplotlib as mlt 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
geo_data = pd.read_csv('../../../data/geo_mode_data/final.csv')
geo_data.head()
print(geo_data.nunique())
print(geo_data.info())
print(geo_data.isnull().sum())
# Out:
#       index  continent  gdp_per_capita  hospital_beds_per_thousand  \
# 0         0          1        1803.987                         0.5
# 1         1          1        1803.987                         0.5
# 2         2          1        1803.987                         0.5
# 3         3          1        1803.987                         0.5
# 4         4          1        1803.987                         0.5
# ...     ...        ...             ...                         ...
# 1828   1828          4        8702.975                         2.3
# 1829   1829          4        8702.975                         2.3
# 1830   1830          4        8702.975                         2.3
# 1831   1831          4        8702.975                         2.3
# 1832   1832          4        8702.975                         2.3
#
#       human_development_index  life_expectancy  population  \
# 0                       0.498            64.83  38928341.0
# ...

# %%
train_df = pd.read_csv('../../../data/main_data/final.csv')
train_df = train_df.sort_values(by=['formal_date','index'])
train_df.head()
print('-------------------------------------------\n', f'training dataset shape : {train_df.shape}')
print('-------------------------------------------\n', 'data distrbution:\n', train_df.nunique())
print('-------------------------------------------\n', 'INFO:', train_df.info())
# Out:
#     index formal_date  quarter  date  day_of_week  month  Suspected_Local  \
# 0       1  2020-03-31        1    31            1      3               41
# 19      2  2020-03-31        1    31            1      3                1
# 15      3  2020-03-31        1    31            1      3                5
# 16      4  2020-03-31        1    31            1      3                2
# 17      5  2020-03-31        1    31            1      3                7
#
#     Suspected_Foreign  temp  humidity  sun_hours  province  \
# 0                   1  28.5      81.0       7.15         1
# 19                  0  28.5      76.0       8.50         1
# 15                  0  29.0      76.0       8.50         1
# 16                  0  28.5      75.0       8.00         2
# 17                  0  28.5      76.0       8.30         2
#
#     neir_infected_cases  locked_percn  TotalInfected
# 0                    34           1.0             11
# 19                   32           1.0             15
# ...

# %%
plt.figure()
sns_gradient = sns.barplot(x="day", y="total_bill", data=tips)
sns_gradient.set_titles("gradient variation with district")
sns_gradient.set_xlabels("district number")

# %%
test_geo_data = pd.read_csv('../../../data/geo_mode_data/test.csv')
test_geo_data.head()
