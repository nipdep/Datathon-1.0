# %% [markdown]
# ## Panel analysis to observe time invariants' properties.

# %%
import pandas as pd
import researchpy as rp
import scipy.stats as stats
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %%
df = pd.read_csv('../../../data/geo_mode_data/new_corona.csv')
df.head()
df.isna().sum()
# Out:
#          date continent  population  population_density     location  \
# 0  12/31/2019      Asia  38928341.0              54.422  Afghanistan
# 1    1/1/2020      Asia  38928341.0              54.422  Afghanistan
# 2    1/2/2020      Asia  38928341.0              54.422  Afghanistan
# 3    1/3/2020      Asia  38928341.0              54.422  Afghanistan
# 4    1/4/2020      Asia  38928341.0              54.422  Afghanistan
#
#    gdp_per_capita  cardiovasc_death_rate  hospital_beds_per_thousand  \
# 0        1803.987                597.029                         0.5
# 1        1803.987                597.029                         0.5
# 2        1803.987                597.029                         0.5
# 3        1803.987                597.029                         0.5
# 4        1803.987                597.029                         0.5
#
#    life_expectancy  new_cases
# 0            64.83        0.0
# 1            64.83        0.0
# 2            64.83        0.0
# ...

# %%
rp.codebook(df)
# Out:
# Variable: date    Data Type: object
#
#  Number of Obs.: 13078
#  Number of missing obs.: 0
#  Percent missing: 0.0
#  Number of unique values: 306
#
#  Data Values and Counts:
#
#       Values  Frequency
#    1/1/2020         20
#   1/10/2020         20
#   1/11/2020         20
#   1/12/2020         20
#   1/13/2020         20
#   1/14/2020         20
#   1/15/2020         20
#   1/16/2020         20
#   1/17/2020         20
#   1/18/2020         20
#   1/19/2020         20
#    1/2/2020         20
#   1/20/2020         20
#   1/21/2020         20
#   1/22/2020         20
#   1/23/2020         20
#   1/24/2020         20
#   1/25/2020         20
#   1/26/2020         20
#   1/27/2020         20
#   1/28/2020         20
#   1/29/2020         20
#    1/3/2020         20
#   1/30/2020         20
#   1/31/2020         20
#    1/4/2020         20
#    1/5/2020         20
#    1/6/2020         20
#    1/7/2020         20
#    1/8/2020         20
#    1/9/2020         20
# ...

# %%
# model = smf.mixedlm("new_cases ~ continent + population + population_density + location",
#                     df,groups= "litter").fit()

# model.summary()
# Out:
#   File "<ipython-input-20-426d2b180b2b>", line 4
#     df,groups= "litter").fit()
#     ^
# IndentationError: unexpected indent

# %%
results = sm.OLS(df.iloc[:,-1].values, df.iloc[:,[2,3,5,6,7,8]].values).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.071
# Model:                            OLS   Adj. R-squared (uncentered):              0.071
# Method:                 Least Squares   F-statistic:                              166.9
# Date:                Mon, 02 Nov 2020   Prob (F-statistic):                   3.63e-205
# Time:                        08:20:59   Log-Likelihood:                     -1.2723e+05
# No. Observations:               13078   AIC:                                  2.545e+05
# Df Residuals:                   13072   BIC:                                  2.545e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
