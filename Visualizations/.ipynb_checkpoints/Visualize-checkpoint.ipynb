# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import json
import plotly.express as px
from folium.plugins import HeatMap, MarkerCluster
import numpy as np
import folium
from folium import Marker,GeoJson,Choropleth, Circle
#plt.figure(figsize=(15))
sns.set(rc={'figure.figsize':(15,15)})

# %%
fig_size = (750,750)

# %%
Directory  = 'F:/Deeplearning/Datathon-1.0'
data_dir = Directory+'/data'
cumu_dir = data_dir +'/Cumulative'
hos_dir = data_dir + '/Hospital'
dataset_dir = Directory+'/Visualizations/datasets'

# %%
try:
    with open(Directory + '/data/maps/hospital_map.json', 'r') as f:
        hospital_map = json.load(f)
except:
    print('Error')

# %%
hospital_map
# Out:
# {'Colombo': ['NIID',
#   'NHSL',
#   'LRH',
#   'DMH',
#   'TH Kalubowila',
#   'Castle St TH',
#   'Colombo East Base Hospital',
#   'KDU Hospital',
#   'S.J.Pura TH'],
#  'Gampaha': ['TH Ragama', 'DGH Gampaha', 'DGH Negombo', 'Chest H. Welisara'],
#  'Puttalam': ['G.H. Chilaw', 'B.H. Marawila'],
#  'Kalutara': ['DGH Kaluthara'],
#  'Anuradhapura': ['TH Apura'],
#  'Kandy': ['NH Kandy', 'BH Theldeniya'],
#  'Kurunegala': ['TH Kurun.'],
#  'Polonnaruwa': ['DGH Polonwa', 'BH Welikanda'],
#  'Jaffna': ['TH Jaffna'],
#  'Ratnapura': ['TH Rathn.'],
#  'Kegalle': [],
#  'Moneragala': ['BH Monagala'],
#  'Kalmunai': [],
#  'Matale': [],
#  'Galle': ['TH Karapitiya'],
#  'Ampara': [],
#  'Badulla': ['PGH Badulla'],
#  'Matara': ['G.H. Matara', 'BH Tangalle'],
#  'Batticoloa': ['TH Batti.'],
#  'Hambantota': ['BH Hamthota'],
#  'Vavunia': ['G.H. Vavunia'],
#  'Trincomalee': [],
#  'Nuwaraeliya': [],
#  'Kilinochchi': [],
#  'Mannar': [],
#  'Mullativu': []}

# %% [markdown]
# ## Sri Lankan Data

# %%
list_cumu_files = os.listdir(cumu_dir)

if('.ipynb_checkpoints' in list_cumu_files):
    list_cumu_files.remove('.ipynb_checkpoints')
    
list_cumu_files[:15]
# Out:
# ['03-31cumu.csv',
#  '04-01cumu.csv',
#  '04-02cumu.csv',
#  '04-03cumu.csv',
#  '04-04cumu.csv',
#  '04-05cumu.csv',
#  '04-06cumu.csv',
#  '04-07cumu.csv',
#  '04-08cumu.csv',
#  '04-09cumu.csv',
#  '04-10cumu.csv',
#  '04-11cumu.csv',
#  '04-12cumu.csv',
#  '04-13cumu.csv',
#  '04-14cumu.csv']

# %%
len(list_cumu_files)
# Out:
# 211

# %%
check_cumu = pd.read_csv(cumu_dir+'/03-31cumu.csv')
check_cumu
# Out:
#     Unnamed: 0                    Hospital  SL_Total  Foreign_Total  Total
# 0            5                        NIID       499             74    573
# 1            6                        NHSL       138              7    145
# 2            7                   TH Ragama       140              3    143
# 3            8               TH Karapitiya       142             17    159
# 4           10                    TH Apura        56              2     58
# 5           12                   TH Kurun.       127              1    128
# 6           14                   TH Jaffna        34              1     35
# 7           16                    NH Kandy        74              6     80
# 8           18                 TH Battico.        27              0     27
# 9           20                 DGH Gampaha       133              4    137
# 10          22                 DGH Negombo       169             13    182
# 11          24                   TH Rathn.        92              0     92
# 12          26                 PGH Badulla        27              1     28
# 13          27                         LRH        30              0     30
# 14          28                         DMH         9              0      9
# 15          30                 DGH Polonwa        78              6     84
# 16          32               TH Kalubowila        20              0     20
# 17          34                Castle St TH        10              0     10
# 18          36                 BH Hamthota        67              1     68
# 19          38                 BH Monagala        26              0     26
# 20          40                BH Welikanda        35              1     36
# 21          42               DGH Kaluthara       117              0    117
# 22          44           Chest H. Welisara         7              0      7
# 23          46  Colombo East Base Hospital         1              0      1
# 24          49                 BH Homagama        65              1     66
# 25          51            Dr Neville F. Ho         7              0      7
# 26          53                 G.H. Chilaw       133              0    133
# 27          55                 G.H. Matara         5              1      6
# 28          57                KDU Hospital         1              0      1
# 29          59                G.H. Vavunia        19              0     19

# %%
columns_cumu=['Date']+list(hospital_map.keys())
cumulative_sl_df = pd.DataFrame(columns=columns_cumu)
cumulative_sl_df
# Out:
# Empty DataFrame
# Columns: [Date, Colombo, Gampaha, Puttalam, Kalutara, Anuradhapura, Kandy, Kurunegala, Polonnaruwa, Jaffna, Ratnapura, Kegalle, Moneragala, Kalmunai, Matale, Galle, Ampara, Badulla, Matara, Batticoloa, Hambantota, Vavunia, Trincomalee, Nuwaraeliya, Kilinochchi, Mannar, Mullativu]
# Index: []
#
# [0 rows x 27 columns]

# %%
columns_cumu=['Date']+list(hospital_map.keys())
cumulative_fo_df = pd.DataFrame(columns=columns_cumu)
cumulative_fo_df
# Out:
# Empty DataFrame
# Columns: [Date, Colombo, Gampaha, Puttalam, Kalutara, Anuradhapura, Kandy, Kurunegala, Polonnaruwa, Jaffna, Ratnapura, Kegalle, Moneragala, Kalmunai, Matale, Galle, Ampara, Badulla, Matara, Batticoloa, Hambantota, Vavunia, Trincomalee, Nuwaraeliya, Kilinochchi, Mannar, Mullativu]
# Index: []
#
# [0 rows x 27 columns]

# %%
columns_cumu=['Date']+list(hospital_map.keys())
cumulative_tot_df = pd.DataFrame(columns=columns_cumu)
cumulative_tot_df
# Out:
# Empty DataFrame
# Columns: [Date, Colombo, Gampaha, Puttalam, Kalutara, Anuradhapura, Kandy, Kurunegala, Polonnaruwa, Jaffna, Ratnapura, Kegalle, Moneragala, Kalmunai, Matale, Galle, Ampara, Badulla, Matara, Batticoloa, Hambantota, Vavunia, Trincomalee, Nuwaraeliya, Kilinochchi, Mannar, Mullativu]
# Index: []
#
# [0 rows x 27 columns]

# %%
for filename in list_cumu_files:
    date = filename[:5]
    
    df = pd.read_csv(cumu_dir+'/'+filename)
    
    date_sl={}
    date_fo={}
    date_tot={}
    
    for district in hospital_map.keys():
        list_hospitals = hospital_map[district]
        
        sl = 0
        fo = 0
        tot = 0 
        
        for hospital in list_hospitals:
            row = df.loc[df.Hospital == hospital]
            #print(row)
            
            if (row.empty):
                #print(hospital)
                continue
            
            sl += int(row.at[row.index[0], 'SL_Total'])
            fo += int(row.at[row.index[0], 'Foreign_Total'])
            tot += int(row.at[row.index[0], 'Total'])
        
        date_sl[district]=sl
        date_fo[district]=fo
        date_tot[district]=tot
    
    date_sl['Date']=date
    date_fo['Date']=date
    date_tot['Date']=date
    
    cumulative_sl_df = cumulative_sl_df.append(date_sl,ignore_index=True)
    cumulative_fo_df = cumulative_fo_df.append(date_fo,ignore_index=True)
    cumulative_tot_df = cumulative_tot_df.append(date_tot,ignore_index=True)
    #print("*** \n \n")

# %%
cumulative_sl_df.tail(10)
# Out:
#       Date Colombo Gampaha Puttalam Kalutara Anuradhapura Kandy Kurunegala  \
# 201  10-23    8797    3811     3173      768         1274   281        800
# 202  10-24    9027    3869     3199      776         1287   281        809
# 203  10-25    9245    3922     3226      779         1302   281        821
# 204  10-26    9470    3974     3254      785         1310   281        832
# 205  10-27    9636    4044     3285      791         1329   281        847
# 206  10-28    9797    4118     3323      797         1337   283        862
# 207  10-29    9863    4177     3335      803         1349   284        872
# 208  10-30    9970    4218     3373      806         1365   285        883
# 209  10-31   10122    4239     3398      816         1376   285        894
# 210  11-01   10170    4278     3425      822         1388   285        904
#
#     Polonnaruwa Jaffna  ... Badulla Matara Batticoloa Hambantota Vavunia  \
# 201         696    200  ...     131    158        285        382     195
# 202         699    206  ...     134    158        287        382     195
# 203         702    207  ...     142    158        291        382     196
# 204         707    207  ...     144    158        295        382     197
# 205         714    210  ...     145    158        295        382     198
# 206         724    212  ...     146    158        296        382     199
# 207         726    212  ...     149    158        297        382     200
# 208         726    217  ...     151    173        300        382     201
# 209         730    220  ...     156    173        303        382     203
# 210         732    223  ...     160    180        306        382     203
#
#     Trincomalee Nuwaraeliya Kilinochchi Mannar Mullativu
# 201           0           0           0      0         0
# 202           0           0           0      0         0
# 203           0           0           0      0         0
# 204           0           0           0      0         0
# 205           0           0           0      0         0
# 206           0           0           0      0         0
# 207           0           0           0      0         0
# 208           0           0           0      0         0
# 209           0           0           0      0         0
# 210           0           0           0      0         0
#
# [10 rows x 27 columns]

# %%
total_df = cumulative_sl_df.loc[cumulative_sl_df.Date == '11-01'].T
total_df = total_df.drop('Date',axis=0)
total_df.sum()
# Out:
# 210    24689.0
# dtype: float64

# %%
column_show = list(hospital_map.keys())
column_show.remove('Kandy')
column_show.remove('Matara')

# %%
cumulative_sl_df.tail(20).style.background_gradient(cmap='Reds',subset=["Colombo"])\
                        .background_gradient(cmap='Pastel1_r',subset=["Gampaha"])\
                        .background_gradient(cmap='Greens',subset=["Puttalam"])\
                        .background_gradient(cmap='Purples',subset=["Kalutara"])\
                        .background_gradient(cmap='Blues',subset=["Anuradhapura"])\
                        .background_gradient(cmap='Oranges',subset=["Kurunegala"])\
                        .background_gradient(cmap='Greys',subset=["Polonnaruwa"])
# Out:
# <style  type="text/css" >
# #T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row0_col1{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row0_col2,#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row1_col2,#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row2_col2,#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row3_col2{
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row0_col3{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row0_col4,#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row1_col4{
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row0_col5{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row0_col7,#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row1_col7{
#             background-color:  #fff5eb;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row0_col8,#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row1_col8,#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row2_col8{
#             background-color:  #ffffff;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row1_col1{
#             background-color:  #ffece4;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row1_col3{
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row1_col5{
#             background-color:  #edf4fc;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row2_col1{
#             background-color:  #fedecf;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row2_col3,#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row3_col3{
#             background-color:  #def2d9;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row2_col4,#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row3_col4{
#             background-color:  #fbfafc;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row2_col5{
#             background-color:  #e5eff9;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row2_col7{
#             background-color:  #fff3e6;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row3_col1{
#             background-color:  #fed9c9;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row3_col5{
#             background-color:  #dfebf7;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row3_col7{
#             background-color:  #fff0e1;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row3_col8{
#             background-color:  #fefefe;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row4_col1{
#             background-color:  #fdd0bc;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row4_col2,#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row5_col2{
#             background-color:  #fddaec;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row4_col3{
#             background-color:  #d3eecd;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row4_col4{
#             background-color:  #f8f7fb;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row4_col5{
#             background-color:  #d5e5f4;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row4_col7{
#             background-color:  #feecd9;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row4_col8{
#             background-color:  #f6f6f6;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row5_col1{
#             background-color:  #fcc4ad;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row5_col3{
#             background-color:  #cbeac4;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row5_col4{
#             background-color:  #f5f4f9;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row5_col5{
#             background-color:  #c7dbef;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row5_col7{
#             background-color:  #fee5cc;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row5_col8{
#             background-color:  #cdcdcd;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row6_col1{
#             background-color:  #fcb69b;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row6_col2,#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row7_col2,#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row8_col2{
#             background-color:  #e5d8bd;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row6_col3{
#             background-color:  #c7e9c0;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row6_col4{
#             background-color:  #efedf5;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row6_col5{
#             background-color:  #bdd7ec;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row6_col7{
#             background-color:  #fee5cb;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row6_col8{
#             background-color:  #c5c5c5;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row7_col1{
#             background-color:  #fca183;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row7_col3{
#             background-color:  #c0e6b9;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row7_col4{
#             background-color:  #e6e5f1;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row7_col5{
#             background-color:  #b0d2e7;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row7_col7{
#             background-color:  #fdd7b1;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row7_col8{
#             background-color:  #b8b8b8;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row8_col1{
#             background-color:  #fc997a;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row8_col3{
#             background-color:  #bae3b3;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row8_col4{
#             background-color:  #e0dfee;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row8_col5{
#             background-color:  #9dcae1;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row8_col7{
#             background-color:  #fdd0a2;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row8_col8{
#             background-color:  #a5a5a5;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row9_col1{
#             background-color:  #fc8d6d;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row9_col2,#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row10_col2{
#             background-color:  #ffffcc;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row9_col3{
#             background-color:  #b0dfaa;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row9_col4{
#             background-color:  #dcdcec;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row9_col5{
#             background-color:  #89bedc;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61row9_col7{
#             background-color:  #fdb576;
#             color:  #000000;
#         }#T_70f12b14_1cd9_11eb_8967_1c1b0dcfaa61r

# %%
cumulative_sl_df = cumulative_sl_df.apply(lambda x: x.apply(int) if x.name in list(hospital_map.keys()) else x)
sns.lineplot(x='Date', y='Cumulative Patients', hue='District', 
             data=pd.melt(cumulative_sl_df.loc[cumulative_sl_df.index%8==0],var_name='District',value_name='Cumulative Patients', id_vars = ['Date'],value_vars=column_show))
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Cumulative Patients'>

# %%
cumulative_sl_df.to_csv(dataset_dir+'/cumulative_sl.csv')
cumulative_fo_df.to_csv(dataset_dir+'/cumulative_fo.csv')
cumulative_tot_df.to_csv(dataset_dir+'/cumulative_tot.csv')

# %%
cumulative_tot_df = cumulative_tot_df.apply(lambda x: x.apply(int) if x.name in list(hospital_map.keys()) else x)
sns.lineplot(x='Date', y='Cumulative Patients', hue='District', 
             data=pd.melt(cumulative_tot_df.loc[cumulative_tot_df.index%8==0],var_name='District',value_name='Cumulative Patients', id_vars = ['Date'],value_vars=column_show))
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Cumulative Patients'>

# %%
list_hos_files = os.listdir(hos_dir)

if('.ipynb_checkpoints' in list_hos_files):
    list_hos_files.remove('.ipynb_checkpoints')
    
list_hos_files[:15]
# Out:
# ['03-31hos.csv',
#  '04-01hos.csv',
#  '04-02hos.csv',
#  '04-03hos.csv',
#  '04-04hos.csv',
#  '04-05hos.csv',
#  '04-06hos.csv',
#  '04-07hos.csv',
#  '04-08hos.csv',
#  '04-09hos.csv',
#  '04-10hos.csv',
#  '04-11hos.csv',
#  '04-12hos.csv',
#  '04-13hos.csv',
#  '04-14hos.csv']

# %%
check_hos = pd.read_csv(hos_dir+'/03-31hos.csv')
check_hos
# Out:
#     Unnamed: 0                    Hospital  SL_Today  Foreign_Today  \
# 0            5                        NIID         4              0
# 1            6                        NHSL         5              0
# 2            7                   TH Ragama         9              1
# 3            8               TH Karapitiya         0              0
# 4           10                    TH Apura         2              0
# 5           12                   TH Kurun.         1              0
# 6           14                   TH Jaffna         8              0
# 7           16                    NH Kandy         7              0
# 8           18                 TH Battico.         1              0
# 9           20                 DGH Gampaha        11              0
# 10          22                 DGH Negombo        18              0
# 11          24                   TH Rathn.         7              0
# 12          26                 PGH Badulla         1              0
# 13          27                         LRH         1              0
# 14          28                         DMH         0              0
# 15          30                 DGH Polonwa         5              0
# 16          32               TH Kalubowila         0              0
# 17          34                Castle St TH         1              0
# 18          36                 BH Hamthota         5              0
# 19          38                 BH Monagala         1              0
# 20          40                BH Welikanda        18              1
# 21          42               DGH Kaluthara         5              0
# 22          44           Chest H. Welisara         3              0
# 23          46  Colombo East Base Hospital         0              0
# 24          49                 BH Homagama        48              1
# 25          51            Dr Neville F. Ho         2              0
# 26          53                 G.H. Chilaw         1              0
# 27          55                 G.H. Matara         2              0
# 28          57                KDU Hospital         1              0
# 29          59                G.H. Vavunia         3              0
# 30          61                       Total       170              3
#
#    Total_Today
# 0            4
# 1            5
# 2           10
# 3            0
# 4            2
# 5            1
# 6            8
# 7            7
# 8            1
# 9           11
# 10          18
# 11           7
# 12           1
# 13           1
# 14           0
# 15           5
# 16           0
# 17           1
# 18           5
# 19           1
# 20          19
# 21           5
# 22           3
# 23           0
# 24          49
# 25           2
# 26           1
# 27           2
# 28           1
# 29           3
# 30        173#

# %%
columns_day=['Date']+list(hospital_map.keys())
day_sl_df = pd.DataFrame(columns=columns_cumu)
day_sl_df
# Out:
# Empty DataFrame
# Columns: [Date, Colombo, Gampaha, Puttalam, Kalutara, Anuradhapura, Kandy, Kurunegala, Polonnaruwa, Jaffna, Ratnapura, Kegalle, Moneragala, Kalmunai, Matale, Galle, Ampara, Badulla, Matara, Batticoloa, Hambantota, Vavunia, Trincomalee, Nuwaraeliya, Kilinochchi, Mannar, Mullativu]
# Index: []
#
# [0 rows x 27 columns]

# %%
columns_day=['Date']+list(hospital_map.keys())
day_fo_df = pd.DataFrame(columns=columns_cumu)
day_fo_df
# Out:
# Empty DataFrame
# Columns: [Date, Colombo, Gampaha, Puttalam, Kalutara, Anuradhapura, Kandy, Kurunegala, Polonnaruwa, Jaffna, Ratnapura, Kegalle, Moneragala, Kalmunai, Matale, Galle, Ampara, Badulla, Matara, Batticoloa, Hambantota, Vavunia, Trincomalee, Nuwaraeliya, Kilinochchi, Mannar, Mullativu]
# Index: []
#
# [0 rows x 27 columns]

# %%
columns_day=['Date']+list(hospital_map.keys())
day_tot_df = pd.DataFrame(columns=columns_cumu)
day_tot_df
# Out:
# Empty DataFrame
# Columns: [Date, Colombo, Gampaha, Puttalam, Kalutara, Anuradhapura, Kandy, Kurunegala, Polonnaruwa, Jaffna, Ratnapura, Kegalle, Moneragala, Kalmunai, Matale, Galle, Ampara, Badulla, Matara, Batticoloa, Hambantota, Vavunia, Trincomalee, Nuwaraeliya, Kilinochchi, Mannar, Mullativu]
# Index: []
#
# [0 rows x 27 columns]

# %%
for filename in list_hos_files:
    date = filename[:5]
    
    df = pd.read_csv(hos_dir+'/'+filename)
    
    date_sl={}
    date_fo={}
    date_tot={}
    
    for district in hospital_map.keys():
        list_hospitals = hospital_map[district]
        
        sl = 0
        fo = 0
        tot = 0
        
        for hospital in list_hospitals:
            row = df.loc[df.Hospital == hospital]
            #print(row)
            
            if (row.empty):
                #print(hospital)
                continue
            
            sl += int(row.at[row.index[0], 'SL_Today'])
            fo += int(row.at[row.index[0], 'Foreign_Today'])
            tot += int(row.at[row.index[0], 'Total_Today'])
        
        date_sl[district]=sl
        date_fo[district]=fo
        date_tot[district]=tot
    
    date_sl['Date']=date
    date_fo['Date']=date
    date_tot['Date']=date
    
    day_sl_df = day_sl_df.append(date_sl,ignore_index=True)
    day_fo_df = day_fo_df.append(date_fo,ignore_index=True)
    day_tot_df = day_tot_df.append(date_tot,ignore_index=True)
    #print("*** \n \n")

# %%
day_sl_df.tail(10)
# Out:
#       Date Colombo Gampaha Puttalam Kalutara Anuradhapura Kandy Kurunegala  \
# 201  10-23     281      60       20        6            9    10         15
# 202  10-24     303      79       14       18           14     9         13
# 203  10-25     342      74       17       17           14     9         13
# 204  10-26     358      70       13       18            3     9         17
# 205  10-27     251      84       17       15           14     9         21
# 206  10-28     242      92       20       15            6    11         15
# 207  10-29     232     101       25       14            8    12         13
# 208  10-30     200     120       27       10           16    12         12
# 209  10-31     175     114       24       18           12     9         11
# 210  11-01     191      98       25       17           14     9         10
#
#     Polonnaruwa Jaffna  ... Badulla Matara Batticoloa Hambantota Vavunia  \
# 201           9      0  ...       3      0          1          0       2
# 202           9      6  ...       4      0          1          0       2
# 203           8      1  ...      10      0          3          0       3
# 204           8      2  ...       4      0          5          1       1
# 205          10      3  ...       3      0          4          0       1
# 206          16      2  ...       1      0          2          0       0
# 207           8      0  ...       5      0          2          0       0
# 208           6      5  ...       6      2          4          0       1
# 209           8      3  ...       5      2          2          0       2
# 210           8      3  ...       7      4          7          0       1
#
#     Trincomalee Nuwaraeliya Kilinochchi Mannar Mullativu
# 201           0           0           0      0         0
# 202           0           0           0      0         0
# 203           0           0           0      0         0
# 204           0           0           0      0         0
# 205           0           0           0      0         0
# 206           0           0           0      0         0
# 207           0           0           0      0         0
# 208           0           0           0      0         0
# 209           0           0           0      0         0
# 210           0           0           0      0         0
#
# [10 rows x 27 columns]

# %%
day_sl_df.tail(20).style.background_gradient(cmap='Reds',subset=["Colombo"])\
                        .background_gradient(cmap='Pastel1_r',subset=["Gampaha"])\
                        .background_gradient(cmap='Greens',subset=["Puttalam"])\
                        .background_gradient(cmap='Purples',subset=["Kalutara"])\
                        .background_gradient(cmap='Blues',subset=["Anuradhapura"])\
                        .background_gradient(cmap='Oranges',subset=["Kurunegala"])\
                        .background_gradient(cmap='Greys',subset=["Polonnaruwa"])
# Out:
# <style  type="text/css" >
# #T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row0_col1{
#             background-color:  #f14331;
#             color:  #f1f1f1;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row0_col2,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row15_col2{
#             background-color:  #decbe4;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row0_col3{
#             background-color:  #8ed08b;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row0_col4{
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row0_col5{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row0_col7,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row6_col7{
#             background-color:  #a43503;
#             color:  #f1f1f1;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row0_col8,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row10_col8,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row11_col8{
#             background-color:  #dcdcdc;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row1_col1{
#             background-color:  #fedbcc;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row1_col2,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row2_col2,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row5_col2,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row7_col2,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row10_col2{
#             background-color:  #e5d8bd;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row1_col3,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row8_col3,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row13_col3{
#             background-color:  #aedea7;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row1_col4,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row9_col4,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row10_col4{
#             background-color:  #e2e2ef;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row1_col5,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row18_col5{
#             background-color:  #2b7bba;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row1_col7{
#             background-color:  #ffeedd;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row1_col8,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row2_col8{
#             background-color:  #ffffff;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row2_col1{
#             background-color:  #fca285;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row2_col3,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row5_col3{
#             background-color:  #d6efd0;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row2_col4{
#             background-color:  #f5f4f9;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row2_col5,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row3_col5,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row15_col5{
#             background-color:  #bad6eb;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row2_col7,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row3_col7{
#             background-color:  #fff5eb;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row3_col1{
#             background-color:  #fc9c7d;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row3_col2,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row8_col2{
#             background-color:  #fddaec;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row3_col3,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row4_col3{
#             background-color:  #cbeac4;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row3_col4{
#             background-color:  #eeecf4;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row3_col8{
#             background-color:  #f9f9f9;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row4_col1{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row4_col2,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row6_col2,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row9_col2{
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row4_col4,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row5_col4{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row4_col5,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row9_col5{
#             background-color:  #3d8dc4;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row4_col7{
#             background-color:  #fee7d0;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row4_col8,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row9_col8,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row12_col8,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row13_col8,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row16_col8,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row18_col8,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row19_col8{
#             background-color:  #e4e4e4;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row5_col1{
#             background-color:  #feeae1;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row5_col5,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row11_col5,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row12_col5,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row14_col5,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row19_col5{
#             background-color:  #0b559f;
#             color:  #f1f1f1;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row5_col7,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row17_col7{
#             background-color:  #fd9547;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row5_col8{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row6_col1{
#             background-color:  #fdd0bc;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row6_col3{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row6_col4,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row17_col4{
#             background-color:  #a6a3cd;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row6_col5{
#             background-color:  #a4cce3;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row6_col8,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row15_col8{
#             background-color:  #828282;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row7_col1{
#             background-color:  #fcb095;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row7_col3{
#             background-color:  #e9f7e5;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row7_col4,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row16_col4{
#             background-color:  #6d57a6;
#             color:  #f1f1f1;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row7_col5,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row13_col5{
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row7_col7,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row11_col7,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row12_col7,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row16_col7{
#             background-color:  #fa8532;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row7_col8,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row8_col8,#T_782ac9cc_1cd9_11eb_9d1a_1c1b0dcfaa61row17_col8{
#             background-color:  #f4f4f4;
#             color:  #000000;
#         }#T_782ac9cc_1cd9_11eb_9d1a_1c1b0

# %%
day_sl_df = day_sl_df.apply(lambda x: x.apply(int) if x.name in list(hospital_map.keys()) else x)
sns.lineplot(x='Date', y='Suspected Patients', hue='District', 
             data=pd.melt(day_sl_df.loc[day_sl_df.index%8==0],var_name='District',value_name='Suspected Patients', id_vars = ['Date'],value_vars=column_show))
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Suspected Patients'>

# %%
day_fo_df = day_fo_df.apply(lambda x: x.apply(int) if x.name in list(hospital_map.keys()) else x)
sns.lineplot(x='Date', y='Suspected Patients', hue='District', 
             data=pd.melt(day_fo_df.tail(50).loc[day_fo_df.tail(50).index%8==0],var_name='District',value_name='Suspected Patients', id_vars = ['Date'],value_vars=column_show))
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Suspected Patients'>

# %%
day_tot_df = day_tot_df.apply(lambda x: x.apply(int) if x.name in list(hospital_map.keys()) else x)
sns.lineplot(x='Date', y='Suspected Patients', hue='District', 
             data=pd.melt(day_tot_df.tail(50).loc[day_tot_df.tail(50).index%8==0],var_name='District',value_name='Suspected Patients', id_vars = ['Date'],value_vars=column_show))
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Suspected Patients'>

# %%
day_sl_df.to_csv(dataset_dir+'/day_sl.csv')
day_fo_df.to_csv(dataset_dir+'/day_fo.csv')
day_tot_df.to_csv(dataset_dir+'/day_tot.csv')

# %%
[column_val] = day_tot_df.tail(1).index
pie_df = day_tot_df.tail(1).T
#print(pie_df)
pie_df['Total'] = pie_df.loc[:,column_val]
pie_df = pie_df.drop(column_val,axis=1)
pie_df = pie_df.drop('Date',axis=0)
pie_df
# Out:
#              Total
# Colombo        191
# Gampaha         98
# Puttalam        25
# Kalutara        17
# Anuradhapura    14
# Kandy            9
# Kurunegala      10
# Polonnaruwa      8
# Jaffna           3
# Ratnapura        0
# Kegalle          0
# Moneragala       7
# Kalmunai         0
# Matale           0
# Galle            4
# Ampara           0
# Badulla          7
# Matara           4
# Batticoloa       7
# Hambantota       0
# Vavunia          1
# Trincomalee      0
# Nuwaraeliya      0
# Kilinochchi      0
# Mannar           0
# Mullativu        0

# %%
fig = px.pie(pie_df, values= 'Total', names = pie_df.index, title = 'Percentage of infected with District on 11(nov) - 01',
                         color_discrete_sequence=px.colors.sequential.RdBu)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %%
[column_val] = cumulative_tot_df.tail(1).index
pie_df_1 = cumulative_tot_df.tail(1).T
#print(pie_df)
pie_df_1['Total'] = pie_df_1.loc[:,column_val]
pie_df_1 = pie_df_1.drop(column_val,axis=1)
pie_df_1 = pie_df_1.drop('Date',axis=0)
pie_df_1
# Out:
#               Total
# Colombo       10258
# Gampaha        4304
# Puttalam       3427
# Kalutara        824
# Anuradhapura   1390
# Kandy           291
# Kurunegala      905
# Polonnaruwa     739
# Jaffna          225
# Ratnapura       468
# Kegalle           0
# Moneragala      233
# Kalmunai          0
# Matale            0
# Galle           556
# Ampara            0
# Badulla         162
# Matara          182
# Batticoloa      306
# Hambantota      384
# Vavunia         203
# Trincomalee       0
# Nuwaraeliya       0
# Kilinochchi       0
# Mannar            0
# Mullativu         0

# %%
pie_df_1.index
# Out:
# Index(['Colombo', 'Gampaha', 'Puttalam', 'Kalutara', 'Anuradhapura', 'Kandy',
#        'Kurunegala', 'Polonnaruwa', 'Jaffna', 'Ratnapura', 'Kegalle',
#        'Moneragala', 'Kalmunai', 'Matale', 'Galle', 'Ampara', 'Badulla',
#        'Matara', 'Batticoloa', 'Hambantota', 'Vavunia', 'Trincomalee',
#        'Nuwaraeliya', 'Kilinochchi', 'Mannar', 'Mullativu'],
#       dtype='object')

# %%
fig = px.pie(pie_df_1, values= 'Total', names = pie_df_1.index, title = 'Percentage of infected with District Cumulative',
                         color_discrete_sequence=px.colors.sequential.RdBu)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %%
location_df = pd.read_csv(dataset_dir+'/Location.csv')
location_df
# Out:
#         District      Long        Lat
# 0        Colombo  6.907557  79.860266
# 1        Gampaha  7.133940  80.022504
# 2       Puttalam  7.938736  79.942281
# 3       Kalutara  6.581715  80.135822
# 4   Anuradhapura  8.321418  80.394877
# 5          Kandy  7.299622  80.648246
# 6     Kurunegala  7.659964  80.257308
# 7    Polonnaruwa  7.994924  81.035596
# 8         Jaffna  9.738581  80.081293
# 9      Ratnapura  6.564179  80.563616
# 10       Kegalle  7.115695  80.325754
# 11    Moneragala  6.724356  81.353858
# 12      Kalmunai  7.418797  81.831287
# 13        Matale  7.643962  80.695727
# 14         Galle  6.217619  80.245742
# 15        Ampara  7.121484  81.737674
# 16       Badulla  6.989010  81.058134
# 17        Matara  6.128160  80.549586
# 18    Batticoloa  7.802206  81.462288
# 19    Hambantota  6.230570  81.166867
# 20       Vavunia  8.746393  80.482031
# 21   Trincomalee  8.466183  81.074024
# 22   Nuwaraeliya  6.949846  80.784117
# 23   Kilinochchi  9.383391  80.309952
# 24        Mannar  8.830335  80.098404
# 25     Mullativu  9.254172  80.625636

# %%
#location_df.insert(3,'Total',None)
location_df
# Out:
#         District      Long        Lat
# 0        Colombo  6.907557  79.860266
# 1        Gampaha  7.133940  80.022504
# 2       Puttalam  7.938736  79.942281
# 3       Kalutara  6.581715  80.135822
# 4   Anuradhapura  8.321418  80.394877
# 5          Kandy  7.299622  80.648246
# 6     Kurunegala  7.659964  80.257308
# 7    Polonnaruwa  7.994924  81.035596
# 8         Jaffna  9.738581  80.081293
# 9      Ratnapura  6.564179  80.563616
# 10       Kegalle  7.115695  80.325754
# 11    Moneragala  6.724356  81.353858
# 12      Kalmunai  7.418797  81.831287
# 13        Matale  7.643962  80.695727
# 14         Galle  6.217619  80.245742
# 15        Ampara  7.121484  81.737674
# 16       Badulla  6.989010  81.058134
# 17        Matara  6.128160  80.549586
# 18    Batticoloa  7.802206  81.462288
# 19    Hambantota  6.230570  81.166867
# 20       Vavunia  8.746393  80.482031
# 21   Trincomalee  8.466183  81.074024
# 22   Nuwaraeliya  6.949846  80.784117
# 23   Kilinochchi  9.383391  80.309952
# 24        Mannar  8.830335  80.098404
# 25     Mullativu  9.254172  80.625636

# %%
for index in location_df.index:
    district = location_df.at[index,'District']
    location_df.at[index,'Total'] = pie_df.at[district,'Total']

location_df
# Out:
#         District      Long        Lat  Total
# 0        Colombo  6.907557  79.860266  191.0
# 1        Gampaha  7.133940  80.022504   98.0
# 2       Puttalam  7.938736  79.942281   25.0
# 3       Kalutara  6.581715  80.135822   17.0
# 4   Anuradhapura  8.321418  80.394877   14.0
# 5          Kandy  7.299622  80.648246    9.0
# 6     Kurunegala  7.659964  80.257308   10.0
# 7    Polonnaruwa  7.994924  81.035596    8.0
# 8         Jaffna  9.738581  80.081293    3.0
# 9      Ratnapura  6.564179  80.563616    0.0
# 10       Kegalle  7.115695  80.325754    0.0
# 11    Moneragala  6.724356  81.353858    7.0
# 12      Kalmunai  7.418797  81.831287    0.0
# 13        Matale  7.643962  80.695727    0.0
# 14         Galle  6.217619  80.245742    4.0
# 15        Ampara  7.121484  81.737674    0.0
# 16       Badulla  6.989010  81.058134    7.0
# 17        Matara  6.128160  80.549586    4.0
# 18    Batticoloa  7.802206  81.462288    7.0
# 19    Hambantota  6.230570  81.166867    0.0
# 20       Vavunia  8.746393  80.482031    1.0
# 21   Trincomalee  8.466183  81.074024    0.0
# 22   Nuwaraeliya  6.949846  80.784117    0.0
# 23   Kilinochchi  9.383391  80.309952    0.0
# 24        Mannar  8.830335  80.098404    0.0
# 25     Mullativu  9.254172  80.625636    0.0

# %%
def rounding(x):
    return(round(x,4))

# %%
location_df = location_df.apply(lambda x: x.apply(float) if x.name != 'District' else x)
location_df = location_df.apply(lambda x: x.apply(str) if x.name == 'Total' else x)
#location_df = location_df.apply(lambda x: x.apply(rounding) if x.name in ['Long','Lat'] else x)
location_df
# Out:
#         District    Long      Lat  Total
# 0        Colombo  6.9076  79.8603  191.0
# 1        Gampaha  7.1339  80.0225   98.0
# 2       Puttalam  7.9387  79.9423   25.0
# 3       Kalutara  6.5817  80.1358   17.0
# 4   Anuradhapura  8.3214  80.3949   14.0
# 5          Kandy  7.2996  80.6482    9.0
# 6     Kurunegala  7.6600  80.2573   10.0
# 7    Polonnaruwa  7.9949  81.0356    8.0
# 8         Jaffna  9.7386  80.0813    3.0
# 9      Ratnapura  6.5642  80.5636    0.0
# 10       Kegalle  7.1157  80.3258    0.0
# 11    Moneragala  6.7244  81.3539    7.0
# 12      Kalmunai  7.4188  81.8313    0.0
# 13        Matale  7.6440  80.6957    0.0
# 14         Galle  6.2176  80.2457    4.0
# 15        Ampara  7.1215  81.7377    0.0
# 16       Badulla  6.9890  81.0581    7.0
# 17        Matara  6.1282  80.5496    4.0
# 18    Batticoloa  7.8022  81.4623    7.0
# 19    Hambantota  6.2306  81.1669    0.0
# 20       Vavunia  8.7464  80.4820    1.0
# 21   Trincomalee  8.4662  81.0740    0.0
# 22   Nuwaraeliya  6.9498  80.7841    0.0
# 23   Kilinochchi  9.3834  80.3100    0.0
# 24        Mannar  8.8303  80.0984    0.0
# 25     Mullativu  9.2542  80.6256    0.0

# %%
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=[7.8731, 80.7718], tiles='openstreetmap' ,zoom_start=8)

# Add points to the map
mc = MarkerCluster()
for index in location_df.index:
    if not math.isnan(location_df.at[index,'Long']) and not math.isnan(location_df.at[index,'Lat']):
        mc.add_child(Marker([location_df.at[index,'Long'], location_df.at[index,'Lat']]
                           ,popup=location_df.at[index,'Total']
                           ,icon=folium.Icon(color='red', icon='info-sign')))

m.add_child(mc)
# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Global Data Used

# %%
corona_df = pd.read_csv(dataset_dir+'/corona.csv')
corona_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  12/31/2019          NaN        0.0
# 1          AFG      Asia  Afghanistan    1/1/2020          NaN        0.0
# 2          AFG      Asia  Afghanistan    1/2/2020          NaN        0.0
# 3          AFG      Asia  Afghanistan    1/3/2020          NaN        0.0
# 4          AFG      Asia  Afghanistan    1/4/2020          NaN        0.0
# ...        ...       ...          ...         ...          ...        ...
# 16852      FJI   Oceania         Fiji   9/14/2020         32.0        0.0
# 16853      FJI   Oceania         Fiji   9/15/2020         32.0        0.0
# 16854      FJI   Oceania         Fiji   9/16/2020         32.0        0.0
# 16855      FJI   Oceania         Fiji   9/17/2020         32.0        0.0
# 16856      FJI   Oceania         Fiji   9/18/2020         32.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         0.0                  NaN  ...
# 1                     NaN           NaN         0.0                  NaN  ...
# 2                     NaN           NaN         0.0                  NaN  ...
# 3                     NaN           NaN         0.0                  NaN  ...
# 4                     NaN           NaN         0.0                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 16852               0.143           2.0         0.0                  0.0  ...
# 16853               0.143           2.0         0.0                  0.0  ...
# 16854               0.143           2.0         0.0                  0.0  ...
# 16855               0.000           2.0         0.0                  0.0  ...
# 16856               0.000           2.0         0.0                  0.0  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 16852        8702.975              1.4                412.820
# 16853        8702.975              1.4                412.820
# 16854        8702.975              1.4                412.820
# 16855        8702.975              1.4                412.820
# 16856             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 16852                14.49            10.2          34.8
# 16853                14.49            10.2          34.8
# 16854                14.49            10.2          34.8
# 16855                14.49            10.2          34.8
# 16856                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 16852                     NaN                         2.3            67.44
# 16853                     NaN                         2.3            67.44
# 16854                     NaN                         2.3            67.44
# 16855                     NaN                         2.3            67.44
# 16856                     NaN                         NaN              NaN
#
#        human_development_index
# 0                        0.498
# 1                        0.498
# 2                        0.498
# 3                        0.498
# 4                        0.498
# ...                        ...
# 16852                    0.741
# 16853                    0.741
# 16854                    0.741
# 16855                    0.741
# 16856                      NaN
#
# [16857 rows x 49 columns]

# %%
corona_df.location.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Costa Rica',
#        "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao', 'Cyprus',
#        'Czech Republic', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Ethiopia', 'Faeroe Islands', 'Falkland Islands', 'Fiji'],
#       dtype=object)

# %%
corona_df.iso_code.unique()
# Out:
# array(['AFG', 'ALB', 'DZA', 'AND', 'AGO', 'AIA', 'ATG', 'ARG', 'ARM',
#        'ABW', 'AUS', 'AUT', 'AZE', 'BHS', 'BHR', 'BGD', 'BRB', 'BLR',
#        'BEL', 'BLZ', 'BEN', 'BMU', 'BTN', 'BOL', 'BES', 'BIH', 'BWA',
#        'BRA', 'VGB', 'BRN', 'BGR', 'BFA', 'BDI', 'KHM', 'CMR', 'CAN',
#        'CPV', 'CYM', 'CAF', 'TCD', 'CHL', 'CHN', 'COL', 'COM', 'COG',
#        'CRI', 'CIV', 'HRV', 'CUB', 'CUW', 'CYP', 'CZE', 'COD', 'DNK',
#        'DJI', 'DMA', 'DOM', 'ECU', 'EGY', 'SLV', 'GNQ', 'ERI', 'EST',
#        'ETH', 'FRO', 'FLK', 'FJI'], dtype=object)

# %%
corona_df = corona_df.apply(lambda x: x.apply(int) if x.name in list(hospital_map.keys()) else x)
sns.lineplot(x='Date', y='Suspected Patients', hue='District', 
             data=pd.melt(day_sl_df.tail(50).loc[day_sl_df.tail(50).index%8==0],var_name='District',value_name='Suspected Patients', id_vars = ['Date'],value_vars=column_show))

# %% [markdown]
# ## Additional Data

# %%
info_df = pd.read_csv(dataset_dir+'/info.csv')
info_df = info_df.dropna(how='any', axis=0)
info_df = info_df.applymap(float)
info_df
# Out:
#      index  month  temp  humidity  sun_hours
# 0      1.0    0.0  27.0      77.0       8.79
# 1      2.0    0.0  27.0      75.0       9.46
# 2      3.0    0.0  26.5      78.0       8.88
# 3      4.0    0.0  27.0      79.0       8.50
# 4      5.0    0.0  26.0      76.0       9.18
# ..     ...    ...   ...       ...        ...
# 245    3.0    9.0  27.5      76.0       5.98
# 246    4.0    9.0  27.5      83.0       5.53
# 247    5.0    9.0  28.5      76.0       5.98
# 248    6.0    9.0  27.5      79.0       5.53
# 249    7.0    9.0  27.0      76.0       5.98
#
# [232 rows x 5 columns]

# %%
info_df_2 = info_df[['temp','humidity','sun_hours']]

#print(info_df_2)
corr = info_df_2.corr()
#print(corr)

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))

sns.set(style="white")

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>
